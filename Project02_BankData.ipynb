# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Workspace

# %%
from azureml.core import Workspace

# %%
ws = Workspace.from_config()

# %%
ws
# Out:
# Workspace.create(name='quick-starts-ws-169110', subscription_id='510b94ba-e453-4417-988b-fbdc37b55ca7', resource_group='aml-quickstarts-169110')

# %% [markdown]
# ## Dataset

# %%
from azureml.core import Dataset

dataset = Dataset.get_by_name(ws, name='bank')
df = dataset.to_pandas_dataframe()

# %%
df.shape
# Out:
# (32950, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32950 entries, 0 to 32949
# Data columns (total 21 columns):
# age               32950 non-null int64
# job               32950 non-null object
# marital           32950 non-null object
# education         32950 non-null object
# default           32950 non-null object
# housing           32950 non-null object
# loan              32950 non-null object
# contact           32950 non-null object
# month             32950 non-null object
# day_of_week       32950 non-null object
# duration          32950 non-null int64
# campaign          32950 non-null int64
# pdays             32950 non-null int64
# previous          32950 non-null int64
# poutcome          32950 non-null object
# emp.var.rate      32950 non-null float64
# cons.price.idx    32950 non-null float64
# cons.conf.idx     32950 non-null float64
# euribor3m         32950 non-null float64
# nr.employed       32950 non-null float64
# y                 32950 non-null object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 5.3+ MB

# %%
df.head(2)
# Out:
#    age         job  marital    education  default housing loan    contact  \
# 0   57  technician  married  high.school       no      no  yes   cellular
# 1   55     unknown  married      unknown  unknown     yes   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Experiment

# %%
from azureml.core import Experiment

experiment_name = 'bank-exp-01'
project_folder = './pipeline-bank-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: bank-exp-01,
# Workspace: quick-starts-ws-169110)

# %% [markdown]
# ## Compute Cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# InProgress..
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded.....................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %%
compute_target
# Out:
# AmlCompute(workspace=Workspace.create(name='quick-starts-ws-169110', subscription_id='510b94ba-e453-4417-988b-fbdc37b55ca7', resource_group='aml-quickstarts-169110'), name=auto-ml, id=/subscriptions/510b94ba-e453-4417-988b-fbdc37b55ca7/resourceGroups/aml-quickstarts-169110/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-169110/computes/auto-ml, type=AmlCompute, provisioning_state=Succeeded, location=southcentralus, tags=None)

# %% [markdown]
# ## AutoML Training Configuration

# %%
from azureml.train.automl import AutoMLConfig
from azureml.pipeline.steps import AutoMLStep

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'accuracy',
    "n_cross_validations": 5
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset, 
                             label_column_name="y",  
                             path = project_folder,
                             enable_early_stopping= True,
                             #featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# ## Pipeline and AutoML Step

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %%
ds
# Out:
# {
#   "name": "workspaceblobstore",
#   "container_name": "azureml-blobstore-0c6b8ebf-9bfe-4aec-99eb-8b15a420398f",
#   "account_name": "mlstrg169110",
#   "protocol": "https",
#   "endpoint": "core.windows.net"
# }

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [59762c30][1ec8dd4b-4611-470b-9def-0435577b81d6], (This step will run and generate new outputs)
# Submitted PipelineRun 2451dc03-77ef-4ffc-b7f8-51735fcf03f9
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2451dc03-77ef-4ffc-b7f8-51735fcf03f9?wsid=/subscriptions/510b94ba-e453-4417-988b-fbdc37b55ca7/resourcegroups/aml-quickstarts-169110/workspaces/quick-starts-ws-169110&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 2451dc03-77ef-4ffc-b7f8-51735fcf03f9
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2451dc03-77ef-4ffc-b7f8-51735fcf03f9?wsid=/subscriptions/510b94ba-e453-4417-988b-fbdc37b55ca7/resourcegroups/aml-quickstarts-169110/workspaces/quick-starts-ws-169110&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '2451dc03-77ef-4ffc-b7f8-51735fcf03f9', 'status': 'Completed', 'startTimeUtc': '2021-12-26T19:14:12.127694Z', 'endTimeUtc': '2021-12-26T19:42:57.099878Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg169110.blob.core.windows.net/azureml/ExperimentRun/dcid.2451dc03-77ef-4ffc-b7f8-51735fcf03f9/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=%2FV5V%2BZukpFQBNjMnxq8hZVtd%2B3EPfDCtXe%2Bi0se8kw4%3D&skoid=64152a86-a81a-41a9-af62-8c1da4256808&sktid=660b3398-b80e-49d2-bc5b-ac1dc93b5254&skt=2021-12-26T19%3A04%3A13Z&ske=2021-12-28T03%3A14%3A13Z&sks=b&skv=2019-07-07&st=2021-12-26T19%3A35%3A14Z&se=2021-12-27T03%3A45%3A14Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg169110.blob.core.windows.net/azureml/ExperimentRun/dcid.2451dc03-77ef-4ffc-b7f8-51735fcf03f9/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=43p6LAqzNhYzjE6jW2uVuIuIN2XQWWoJCjc7DiKoPqA%3D&skoid=64152a86-a81a-41a9-af62-8c1da4256808&sktid=660b3398-b80e-49d2-bc5b-ac1dc93b5254&skt=2021-12-26T19%3A04%3A13Z&ske=2021-12-28T03%3A14%3A13Z&sks=b&skv=2019-07-07&st=2021-12-26T19%3A35%3A14Z&se=2021-12-27T03%3A45%3A14Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg169110.blob.core.windows.net/azureml/ExperimentRun/dcid.2451dc03-77ef-4ffc-b7f8-51735fcf03f9/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=sR%2Bq5jPG%2BcjqBwRXTO0cS%2FTXM4j%2BEO70VFuTu9hOwuc%3D&skoid=64152a86-a81a-41a9-af62-8c1da4256808&sktid=660b3398-b80e-49d2-bc5b-ac1dc93b5254&skt=2021-12-26T19%3A04%3A13Z&ske=2021-12-28T03%3A14%3A13Z&sks=b&skv=2019-07-07&st=2021-12-26T19%3A35%3A14Z&se=2021-12-27T03%3A45%3A14Z&sp=r'}, 'submittedBy': 'ODL_User 169110'}
# 'Finished'

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/5ec83b31-d37a-4ba1-b554-683bf22e2d8a/metrics_data
# Downloaded azureml/5ec83b31-d37a-4ba1-b554-683bf22e2d8a/metrics_data, 1 files out of an estimated total of 1

# %%
import pandas as pd
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_2  \
# accuracy                                           [0.7327162367223065]
# AUC_micro                                           [0.832972923061336]
# recall_score_weighted                              [0.7327162367223065]
# average_precision_score_macro                       [0.703466734680023]
# precision_score_micro                              [0.7327162367223065]
# f1_score_micro                                     [0.7327162367223065]
# log_loss                                           [0.5567037697349142]
# matthews_correlation                              [0.29961701350918135]
# precision_score_weighted                           [0.8733482297182045]
# recall_score_micro                                 [0.7327162367223065]
# f1_score_macro                                     [0.6007594372417148]
# AUC_weighted                                       [0.8161368730427355]
# f1_score_weighted                                  [0.7788448982742395]
# recall_score_macro                                 [0.7201734948208027]
# balanced_accuracy                                  [0.7201734948208027]
# AUC_macro                                          [0.8161368730427355]
# norm_macro_recall                                 [0.44034698964160535]
# average_precision_score_weighted                   [0.9094764713985735]
# weighted_accuracy                                  [0.7358434900414215]
# average_precision_score_micro                      [0.8067606279364135]
# precision_score_macro                               [0.601944530292797]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_6  \
# accuracy                                            [0.908619119878604]
# AUC_micro                                           [0.976753917394498]
# recall_score_weighted                               [0.908619119878604]
# average_precision_score_macro                      [0.8022951053050777]
# precision_score_micro                               [0.908619119878604]
# f1_score_micro                                     [0.9086191198786041]
# log_loss                                          [0.32736238728255757]
# matthews_correlation                              [0.45965798214456044]
# precision_score_weighted                            [0.897477459260972]
# recall_score_micro                                  [0.908619119878604]
# f1_score_macro                                     [0.7160310671906778]
# AUC_weighted                                       [0.9333103681955321]
# f1_score_weighted                                  [0.8974411224943658]
# recall_score_macro                                 [0.6808920263029449]
# balanced_accuracy                                  [0.6808920263029449]
# AUC_macro                                          [0.9333103865685766]
# norm_macro_recall                                 [0.36178405260588975]
# average_precision_score_weighted                   [0.9485307313671629]
# weighted_accuracy                                  [0.9651945420991362]
# average_precision_score_micro                      [0.9774188933790026]
# precision_score_macro                              [0.7964833584161972]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_8  \
# accuracy                                           [0.8881942336874051]
# AUC_micro                                          [0.9526977325740706]
# recall_score_weighted                              [0.8881942336874051]
# average_precision_score_macro                      [0.7084154064260056]
# precision_score_micro                              [0.8881942336874051]
# f1_score_micro                                     [0.8881942336874051]
# log_loss                                           [0.2882445113311118]
# matthews_correlation                             [0.019338549550406807]
# precision_score_weighted                           [0.8076873205647658]
# recall_score_micro                                 [0.8881942336874051]
# f1_score_macro                                    [0.47300464875471315]
# AUC_weighted                                       [0.8250528447807518]
# f1_score_weighted                                  [0.8359544837270823]
# recall_score_macro                                 [0.5012973054822834]
# balanced_accuracy                                  [0.5012973054822834]
# AUC_macro                                          [0.8250528447807518]
# norm_macro_recall                               [0.0025946109645665237]
# average_precision_score_weighted                   [0.9107948617492966]
# weighted_accuracy                                  [0.9842957158395673]
# average_precision_score_micro                      [0.9498896202154296]
# precision_score_macro                               [0.527440286616245]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_0  \
# accuracy                                           [0.9144157814871017]
# AUC_micro                                          [0.9810792321100854]
# recall_score_weighted                              [0.9144157814871017]
# average_precision_score_macro                      [0.8262948541138542]
# precision_score_micro                              [0.9144157814871017]
# f1_score_micro                                     [0.9144157814871017]
# log_loss                                          [0.17259344664205858]
# matthews_correlation                               [0.5417959465994486]
# precision_score_weighted                           [0.9092869525277483]
# recall_score_micro                                 [0.9144157814871017]
# f1_score_macro                                     [0.7695433632192865]
# AUC_weighted                                       [0.9489629240236944]
# f1_score_weighted                                  [0.9113127087657691]
# recall_score_macro                                 [0.7518569642365837]
# balanced_accuracy                                  [0.7518569642365837]
# AUC_macro                                          [0.9489629240236944]
# norm_macro_recall                                  [0.5037139284731673]
# average_precision_score_weighted                   [0.9559770226907679]
# weighted_accuracy                                  [0.9548042339535432]
# average_precision_score_micro                      [0.9818902825827353]
# precision_score_macro                              [0.7914212857326756]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_3  \
# accuracy                                           [0.9138088012139605]
# AUC_micro                                          [0.9790505133772834]
# recall_score_weighted                              [0.9138088012139605]
# average_precision_score_macro                       [0.816559316631626]
# precision_score_micro                              [0.9138088012139605]
# f1_score_micro                                     [0.9138088012139605]
# log_loss                                          [0.31539739269508277]
# matthews_correlation                               [0.5351650356202582]
# precision_score_weighted                            [0.908127213957241]
# recall_score_micro                                 [0.9138088012139605]
# f1_score_macro                                      [0.765811031788917]
# AUC_weighted                                       [0.9401172900571835]
# f1_score_weighted                                  [0.9102637112289742]
# recall_score_macro                                 [0.7463930096969353]
# balanced_accuracy                                  [0.7463930096969353]
# AUC_macro                                          [0.9401172900571835]
# norm_macro_recall                                 [0.49278601939387057]
# average_precision_score_weighted                   [0.9520012883699446]
# weighted_accuracy                                  [0.9553976572808855]
# average_precision_score_micro                      [0.9789729127232942]
# precision_score_macro                              [0.7907252397851432]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_9  \
# accuracy                                            [0.910773899848255]
# AUC_micro                                           [0.977196732069789]
# recall_score_weighted                               [0.910773899848255]
# average_precision_score_macro                      [0.8081879502745484]
# precision_score_micro                               [0.910773899848255]
# f1_score_micro                                      [0.910773899848255]
# log_loss                                            [0.330327232922604]
# matthews_correlation                                [0.458519480439017]
# precision_score_weighted                           [0.8998767644864023]
# recall_score_micro                                  [0.910773899848255]
# f1_score_macro                                      [0.709019591793739]
# AUC_weighted                                       [0.9353901465401261]
# f1_score_weighted                                  [0.8969742648075718]
# recall_score_macro                                 [0.6697658375118607]
# balanced_accuracy                                  [0.6697658375118607]
# AUC_macro                                          [0.9353901465401264]
# norm_macro_recall                                  [0.3395316750237213]
# average_precision_score_weighted                   [0.9500334761930042]
# weighted_accuracy                                  [0.9706403539507132]
# average_precision_score_micro                      [0.9777608867477745]
# precision_score_macro                               [0.816430658444982]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_4  \
# accuracy                                           [0.9126251896813352]
# AUC_micro                                          [0.9800596111734109]
# recall_score_weighted                              [0.9126251896813352]
# average_precision_score_macro                      [0.8252516776526685]
# precision_score_micro                              [0.9126251896813352]
# f1_score_micro                                     [0.9126251896813352]
# log_loss                                          [0.18545074801612443]
# matthews_correlation                              [0.48456813874230537]
# precision_score_weighted                           [0.9016562771376175]
# recall_score_micro                                 [0.9126251896813352]
# f1_score_macro                                     [0.7304131202023758]
# AUC_weighted                                       [0.9465428553753729]
# f1_score_weighted                                  [0.9023804612516224]
# recall_score_macro                                 [0.6907240886235522]
# balanced_accuracy                                  [0.6907240886235522]
# AUC_macro                                          [0.9465428553753729]
# norm_macro_recall                                  [0.3814481772471042]
# average_precision_score_weighted                   [0.9554203486648047]
# weighted_accuracy                                  [0.9677554378345116]
# average_precision_score_micro                       [0.980867248335279]
# precision_score_macro                              [0.8082320866768189]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_1  \
# accuracy                                           [0.9149317147192717]
# AUC_micro                                          [0.9806089467418561]
# recall_score_weighted                              [0.9149317147192717]
# average_precision_score_macro                      [0.8270301995665266]
# precision_score_micro                              [0.9149317147192717]
# f1_score_micro                                     [0.9149317147192717]
# log_loss                                          [0.17680045065995267]
# matthews_correlation                               [0.5283949538267647]
# precision_score_weighted                           [0.9074494120258981]
# recall_score_micro                                 [0.9149317147192717]
# f1_score_macro                                     [0.7606149023199388]
# AUC_weighted                                       [0.9469943280414782]
# f1_score_weighted                                   [0.909767316524621]
# recall_score_macro                                 [0.7336577332358241]
# balanced_accuracy                                  [0.7336577332358241]
# AUC_macro                                          [0.9469943283657603]
# norm_macro_recall                                  [0.4673154664716481]
# average_precision_score_weighted                   [0.9559275656602093]
# weighted_accuracy                                  [0.9599396217892462]
# average_precision_score_micro                      [0.9814408813866381]
# precision_score_macro                               [0.798786649757224]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_5  \
# accuracy                                           [0.8881638846737481]
# AUC_micro                                          [0.9758588563625855]
# recall_score_weighted                              [0.8881638846737481]
# average_precision_score_macro                      [0.8169207971155308]
# precision_score_micro                              [0.8881638846737481]
# f1_score_micro                                     [0.8881638846737481]
# log_loss                                          [0.24646693752178436]
# matthews_correlation                              [0.03065743850634507]
# precision_score_weighted                           [0.8557913685491567]
# recall_score_micro                                 [0.8881638846737481]
# f1_score_macro                                    [0.47227012566442433]
# AUC_weighted                                       [0.9417922142898865]
# f1_score_weighted                                  [0.8357704275339538]
# recall_score_macro                                 [0.5009500171280062]
# balanced_accuracy                                  [0.5009500171280062]
# AUC_macro                                          [0.9417922142898865]
# norm_macro_recall                               [0.0019000342560124839]
# average_precision_score_weighted                   [0.9529682428280664]
# weighted_accuracy                                  [0.9843494184062322]
# average_precision_score_micro                      [0.9769197442323942]
# precision_score_macro                               [0.744070105893041]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_7  ...  \
# accuracy                                           [0.9082549317147193]  ...
# AUC_micro                                          [0.9739743852482607]  ...
# recall_score_weighted                              [0.9082549317147193]  ...
# average_precision_score_macro                      [0.7888879716269412]  ...
# precision_score_micro                              [0.9082549317147193]  ...
# f1_score_micro                                     [0.9082549317147193]  ...
# log_loss                                          [0.21193871579399834]  ...
# matthews_correlation                               [0.4605877628620255]  ...
# precision_score_weighted                           [0.8961170311350969]  ...
# recall_score_micro                                 [0.9082549317147193]  ...
# f1_score_macro                                     [0.7203543529941027]  ...
# AUC_weighted                                       [0.9305223456222823]  ...
# f1_score_weighted                                  [0.8982182474534876]  ...
# recall_score_macro                                 [0.6840931713535493]  ...
# balanced_accuracy                                  [0.6840931713535493]  ...
# AUC_macro                                          [0.9305223456222823]  ...
# norm_macro_recall                                 [0.36818634270709877]  ...
# average_precision_score_weighted                    [0.945233463115458]  ...
# weighted_accuracy                                  [0.9639396432290546]  ...
# average_precision_score_micro                      [0.9712395920347472]  ...
# precision_score_macro                              [0.7881577552169727]  ...
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_14  \
# accuracy                                            [0.9149013657056144]
# AUC_micro                                           [0.9788902162424791]
# recall_score_weighted                               [0.9149013657056144]
# average_precision_score_macro                        [0.814613209583755]
# precision_score_micro                               [0.9149013657056144]
# f1_score_micro                                      [0.9149013657056144]
# log_loss                                            [0.3151152761650368]
# matthews_correlation                                 [0.542864341502229]
# precision_score_weighted                            [0.9095786707055116]
# recall_score_micro                                  [0.9149013657056144]
# f1_score_macro                                      [0.7699049326491954]
# AUC_weighted                                        [0.9393687554321405]
# f1_score_weighted                                   [0.9116314364736755]
# recall_score_macro                                  [0.7512917587151222]
# balanced_accuracy                                   [0.7512917587151222]
# AUC_macro                                           [0.9393687554321405]
# norm_macro_recall                                   [0.5025835174302444]
# average_precision_score_weighted                    [0.9513515400795786]
# weighted_accuracy                                   [0.9555508854407222]
# average_precision_score_micro                       [0.9786314795937615]
# precision_score_macro                               [0.7932496097519327]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_23  \
# accuracy                                            [0.9092867981790592]
# AUC_micro                                           [0.9743518275033907]
# recall_score_weighted                               [0.9092867981790592]
# average_precision_score_macro                       [0.7912949569608573]
# precision_score_micro                               [0.9092867981790592]
# f1_score_micro                                      [0.9092867981790592]
# log_loss                                           [0.21040843887887672]
# matthews_correlation                               [0.47273175540276935]
# precision_score_weighted                            [0.8980078363329836]
# recall_score_micro                                  [0.9092867981790592]
# f1_score_macro                                      [0.7279840774935206]
# AUC_weighted                                        [0.9325180308168604]
# f1_score_weighted                                   [0.9003063648452565]
# recall_score_macro                                  [0.6931512540681405]
# balanced_accuracy                                   [0.6931512540681405]
# AUC_macro                                           [0.9325180308168604]
# norm_macro_recall                                  [0.38630250813628086]
# average_precision_score_weighted                    [0.9460839643719214]
# weighted_accuracy                                   [0.9629689076882686]
# average_precision_score_micro                       [0.9715687121890335]
# precision_score_macro                               [0.7893229791196636]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_29  \
# accuracy                                            [0.9134142640364189]
# AUC_micro                                           [0.9794725603929253]
# recall_score_weighted                               [0.9134142640364189]
# average_precision_score_macro                       [0.8140481937414676]
# precision_score_micro                               [0.9134142640364189]
# f1_score_micro                                      [0.9134142640364189]
# log_loss                                           [0.18732864004241176]
# matthews_correlation                                [0.5389307088133488]
# precision_score_weighted                            [0.9086286585662174]
# recall_score_micro                                  [0.9134142640364189]
# f1_score_macro                                      [0.7683359861333491]
# AUC_weighted                                        [0.9448271149618002]
# f1_score_weighted                                    [0.910571767220165]
# recall_score_macro                                  [0.7522799580861614]
# balanced_accuracy                                   [0.7522799580861614]
# AUC_macro                                           [0.9448271237652579]
# norm_macro_recall                                    [0.504559916172323]
# average_precision_score_weighted                    [0.9528274751583184]
# weighted_accuracy                                   [0.9534575904545315]
# average_precision_score_micro                       [0.9803960689952895]
# precision_score_macro                               [0.7878782427507824]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_31  \
# accuracy                                            [0.9113201820940819]
# AUC_micro                                           [0.9791142831484685]
# recall_score_weighted                               [0.9113201820940819]
# average_precision_score_macro                       [0.8091702589841543]
# precision_score_micro                               [0.9113201820940819]
# f1_score_micro                                      [0.9113201820940819]
# log_loss                                           [0.18931171255484097]
# matthews_correlation                                [0.5267142681821554]
# precision_score_weighted                            [0.9062161567160775]
# recall_score_micro                                  [0.9113201820940819]
# f1_score_macro                                       [0.762181494158507]
# AUC_weighted                                        [0.9436989117626599]
# f1_score_weighted                                   [0.9082995027914782]
# recall_score_macro                                  [0.7460180707027421]
# balanced_accuracy                                   [0.7460180707027421]
# AUC_macro                                           [0.9436989294941164]
# norm_macro_recall                                   [0.4920361414054842]
# average_precision_score_weighted                    [0.9516064561353179]
# weighted_accuracy                                   [0.9524010421814291]
# average_precision_score_micro                       [0.9800477766677759]
# precision_score_macro                               [0.7819643781453396]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_24  \
# accuracy                                            [0.8879514415781486]
# AUC_micro                                            [0.963926577492453]
# recall_score_weighted                               [0.8879514415781486]
# average_precision_score_macro                       [0.7209128611213986]
# precision_score_micro                               [0.8879514415781486]
# f1_score_micro                                      [0.8879514415781486]
# log_loss                                           [0.27931338007320017]
# matthews_correlation                                               [0.0]
# precision_score_weighted                            [0.7884613418500925]
# recall_score_micro                                  [0.8879514415781486]
# f1_score_macro                                      [0.4703248283762755]
# AUC_weighted                                        [0.8817461030799063]
# f1_score_weighted                                   [0.8352532264037464]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                           [0.8817461030799063]
# norm_macro_recall                                                  [0.0]
# average_precision_score_weighted                    [0.9241487973388676]
# weighted_accuracy                                   [0.9843197680605863]
# average_precision_score_micro                       [0.9647307484925933]
# precision_score_macro                               [0.4439757207890743]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_28  \
# accuracy                                            [0.9100455235204856]
# AUC_micro                                           [0.9783353059424659]
# recall_score_weighted                               [0.9100455235204856]
# average_precision_score_macro                       [0.8068410409342324]
# precision_score_micro                               [0.9100455235204856]
# f1_score_micro                                      [0.9100455235204856]
# log_loss                                           [0.20458597302766757]
# matthews_correlation                                [0.5239561164148386]
# precision_score_weighted                            [0.9055667699359725]
# recall_score_micro                                  [0.9100455235204856]
# f1_score_macro                                      [0.7611090218795111]
# AUC_weighted                                        [0.9412500934144455]
# f1_score_weighted                                   [0.9074606913413797]
# recall_score_macro                                  [0.7472496392007062]
# balanced_accuracy                                   [0.7472496392007062]
# AUC_macro                                             [0.94125010265975]
# norm_macro_recall                                  [0.49449927840141256]
# average_precision_score_weighted                    [0.9507975369650307]
# weighted_accuracy                                   [0.9504888445411472]
# average_precision_score_micro                        [0.979282068715294]
# precision_score_macro                               [0.7776397331757601]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_25  \
# accuracy                                            [0.8879514415781486]
# AUC_micro                                           [0.8879514415781488]
# recall_score_weighted                               [0.8879514415781486]
# average_precision_score_macro                                      [0.5]
# precision_score_micro                               [0.8879514415781486]
# f1_score_micro                                      [0.8879514415781486]
# log_loss                                           [0.35078682183108895]
# matthews_correlation                                               [0.0]
# precision_score_weighted                            [0.7884613418500925]
# recall_score_micro                                  [0.8879514415781486]
# f1_score_macro                                      [0.4703248283762755]
# AUC_weighted                                                       [0.5]
# f1_score_weighted                                   [0.8352532264037464]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                                          [0.5]
# norm_macro_recall                                                  [0.0]
# average_precision_score_weighted                    [0.8010198005438876]
# weighted_accuracy                                   [0.9843197680605863]
# average_precision_score_micro                        [0.844485621061018]
# precision_score_macro                               [0.4439757207890743]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_16  \
# accuracy                                            [0.9089226100151745]
# AUC_micro                                           [0.9730803373852414]
# recall_score_weighted                               [0.9089226100151745]
# average_precision_score_macro                       [0.7825107476338486]
# precision_score_micro                               [0.9089226100151745]
# f1_score_micro                                      [0.9089226100151745]
# log_loss                                             [0.216829934325902]
# matthews_correlation                               [0.46445107103569094]
# precision_score_weighted                            [0.8969949596145484]
# recall_score_micro                                  [0.9089226100151745]
# f1_score_macro                                      [0.7220612497865988]
# AUC_weighted                                        [0.9279958279036338]
# f1_score_weighted                                   [0.8989035442904797]
# recall_score_macro                                  [0.6853314095226418]
# balanced_accuracy                                   [0.6853314095226418]
# AUC_macro                                           [0.9279958279036338]
# norm_macro_recall                                   [0.3706628190452836]
# average_precision_score_weighted                    [0.9436760036487992]
# weighted_accuracy                                   [0.9644471129680848]
# average_precision_score_micro                       [0.9693557233904114]
# precision_score_macro                               [0.7911193125755549]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_32  \
# accuracy                                            [0.9123520485584219]
# AUC_micro                                            [0.979620229759073]
# recall_score_weighted                               [0.9123520485584219]
# average_precision_score_macro                       [0.8137213125408873]
# precision_score_micro                               [0.9123520485584219]
# f1_score_micro                                      [0.9123520485584219]
# log_loss                                           [0.18532526584424516]
# matthews_correlation                                [0.5334935805712999]
# precision_score_weighted                            [0.9075594600240784]
# recall_score_micro                                  [0.9123520485584219]
# f1_score_macro                                       [0.765675894922491]
# AUC_weighted                                        [0.9451202497405955]
# f1_score_weighted                                    [0.909529668484843]
# recall_score_macro                                  [0.7499271338990738]
# balanced_accuracy                                   [0.7499271338990738]
# AUC_macro                                           [0.9451202318845976]
# norm_macro_recall                                   [0.4998542677981475]
# average_precision_score_weighted                    [0.9527706959366553]
# weighted_accuracy                                   [0.9526963279510465]
# average_precision_score_micro                       [0.9805205827338497]
# precision_score_macro                               [0.7847273173096088]
#
#                                  5ec83b31-d37a-4ba1-b554-683bf22e2d8a_30
# accuracy                                            [0.9129893778452202]
# AUC_micro                                           [0.9795234652218264]
# recall_score_weighted                               [0.9129893778452202]
# average_precision_score_macro                        [0.812663714606451]
# precision_score_micro                               [0.9129893778452202]
# f1_score_micro                                      [0.9129893778452202]
# log_loss                                           [0.18564344640976732]
# matthews_correlation                                [0.5367693541296045]
# precision_score_weighted                            [0.9082072255360674]
# recall_score_micro                                  [0.9129893778452202]
# f1_score_macro                                      [0.7672764207442665]
# AUC_weighted                                         [0.944807054684009]
# f1_score_weighted                                   [0.9101576030416092]
# recall_score_macro                                  [0.7513832038266631]
# balanced_accuracy                                   [0.7513832038266631]
# AUC_macro                                            [0.944807054684009]
# norm_macro_recall                                   [0.5027664076533264]
# average_precision_score_weighted                    [0.9524698704108643]
# weighted_accuracy                                   [0.9531358006633373]
# average_precision_score_micro                       [0.9803966074030528]
# precision_score_macro                               [0.7865908368415153]
#
# [21 rows x 37 columns]

# %%
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/5ec83b31-d37a-4ba1-b554-683bf22e2d8a/model_data
# Downloaded azureml/5ec83b31-d37a-4ba1-b554-683bf22e2d8a/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=True, is_onnx_compatible=False, observer=None, task='classification', working_dir='/mn...
# )), ('logisticregression', LogisticRegression(C=51.79474679231202, class_weight=None, dual=False, fit_intercept=True, intercept_scaling=1, l1_ratio=None, max_iter=100, multi_class='ovr', n_jobs=1, penalty='l2', random_state=None, solver='lbfgs', tol=0.0001, verbose=0, warm_start=False))], verbose=False))], flatten_transform=None, weights=[0.14285714285714285, 0.2857142857142857, 0.07142857142857142, 0.07142857142857142, 0.21428571428571427, 0.07142857142857142, 0.07142857142857142, 0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(
#       task='classification',
#       is_onnx_compatible=False,
#       enable_feature_sweeping=True,
#       enable_dnn=False,
#       force_text_dnn=False,
#       feature_sweeping_timeout=86400,
#       featurization_config=None,
#       is_cross_validation=True,
#       feature_sweeping_config={}
#   )),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(
#       estimators=[('1', Pipeline(
#           memory=None,
#           steps=[('maxabsscaler', MaxAbsScaler(
#               copy=True
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('14', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=1,
#               eta=0.3,
#               gamma=0,
#               max_depth=10,
#               max_leaves=511,
#               n_estimators=10,
#               objective='reg:logistic',
#               reg_alpha=2.1875,
#               reg_lambda=0.4166666666666667,
#               subsample=0.5,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('0', Pipeline(
#           memory=None,
#           steps=[('maxabsscaler', MaxAbsScaler(
#               copy=True
#           )), ('lightgbmclassifier', LightGBMClassifier(
#               min_data_in_leaf=20,
#               random_state=None,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               )
#           ))],
#           verbose=False
#       )), ('18', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=0.7,
#               eta=0.1,
#               gamma=0.1,
#               max_depth=9,
#               max_leaves=511,
#               n_estimators=25,
#               objective='reg:logistic',
#               reg_alpha=0,
#               reg_lambda=1.7708333333333335,
#               subsample=0.9,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('3', Pipeline(
#           memory=None,
#           steps=[('sparsenormalizer', Normalizer(
#               copy=True,
#               norm='l2'
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=0.7,
#               eta=0.01,
#               gamma=0.01,
#               max_depth=7,
#               max_leaves=31,
#               n_estimators=10,
#               objective='reg:logistic',
#               reg_alpha=2.1875,
#               reg_lambda=1.0416666666666667,
#               subsample=1,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('15', Pipeline(
#           memory=None,
#           steps=[('sparsenormalizer', Normalizer(
#               copy=True,
#               norm='l2'
#           )), ('randomforestclassifier', RandomForestClassifier(
#               bootstrap=True,
#               ccp_alpha=0.0,
#               class_weight='balanced',
#               criterion='gini',
#               max_depth=None,
#               max_features='sqrt',
#               max_leaf_nodes=None,
#               max_samples=None,
#               min_impurity_decrease=0.0,
#               min_impurity_split=None,
#               min_samples_leaf=0.01,
#               min_samples_split=0.01,
#               min_weight_fraction_leaf=0.0,
#               n_estimators=100,
#               n_jobs=1,
#               oob_score=True,
#               random_state=None,
#               verbose=0,
#               warm_start=False
#           ))],
#           verbose=False
#       )), ('30', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=1,
#               eta=0.001,
#               gamma=0,
#               max_depth=6,
#               max_leaves=31,
#               n_estimators=400,
#               objective='reg:logistic',
#               reg_alpha=0.5208333333333334,
#               reg_lambda=2.5,
#               subsample=0.7,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('16', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('logisticregression', LogisticRegression(
#               C=51.79474679231202,
#               class_weight=None,
#               dual=False,
#               fit_intercept=True,
#               intercept_scaling=1,
#               l1_ratio=None,
#               max_iter=100,
#               multi_class='ovr',
#               n_jobs=1,
#               penalty='l2',
#               random_state=None,
#               solver='lbfgs',
#               tol=0.0001,
#               verbose=0,
#               warm_start=False
#           ))],
#           verbose=False
#       ))],
#       weights=[0.14285714285714285, 0.2857142857142857, 0.07142857142857142, 0.07142857142857142, 0.21428571428571427, 0.07142857142857142, 0.07142857142857142, 0.07142857142857142],
#       flatten_transform=None,
#       classification_labels=array([0, 1])
#   ))]

# %% [markdown]
# ## Publish and run from REST endpoint

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bank Train", description="Training Bank Marketing Pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bank Train,
# Id: c8aa2b75-a1b4-4386-82fd-f8c1c63b591f,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/510b94ba-e453-4417-988b-fbdc37b55ca7/resourceGroups/aml-quickstarts-169110/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-169110/PipelineRuns/PipelineSubmit/c8aa2b75-a1b4-4386-82fd-f8c1c63b591f)

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-bank-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  801e6271-2029-47d3-968b-b00f6575e0f5

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-bank-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
from azureml.core.webservice import Webservice

name = "bank-automl-endpoint-02"
# load existing web service
service = Webservice(name=name, workspace=ws)

# %%
service
# Out:
# AciWebservice(workspace=Workspace.create(name='quick-starts-ws-169110', subscription_id='510b94ba-e453-4417-988b-fbdc37b55ca7', resource_group='aml-quickstarts-169110'), name=bank-automl-endpoint-02, image_id=None, compute_type=None, state=ACI, scoring_uri=Healthy, tags=http://fd59d40d-1b79-463f-803e-83b3b2468e76.southcentralus.azurecontainer.io/score, properties={}, created_by={'runId': '5ec83b31-d37a-4ba1-b554-683bf22e2d8a_38', 'hasInferenceSchema': 'True', 'hasHttps': 'False'})

# %%
service.update(enable_app_insights=True)
logs = service.get_logs()

for line in logs.split('\n'):
    print(line)
# Out:
# 2021-12-26T21:20:38,665889200+00:00 - gunicorn/run
# Dynamic Python package installation is disabled.
# Starting HTTP server
# 2021-12-26T21:20:38,673910600+00:00 - rsyslog/run
# 2021-12-26T21:20:38,668108100+00:00 - iot-server/run
# 2021-12-26T21:20:38,677086900+00:00 - nginx/run
# rsyslogd: /azureml-envs/azureml_84c85d362f11658b9008714e1aa4657b/lib/libuuid.so.1: no version information available (required by rsyslogd)
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2021-12-26T21:20:39,089057000+00:00 - iot-server/finish 1 0
# 2021-12-26T21:20:39,091194700+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 20.1.0
# Listening at: http://127.0.0.1:31311 (74)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 100
# SPARK_HOME not set. Skipping PySpark Initialization.
# Generating new fontManager, this may take some time...
# Initializing logger
# 2021-12-26 21:20:40,826 | root | INFO | Starting up app insights client
# logging socket was found. logging is available.
# logging socket was found. logging is available.
# 2021-12-26 21:20:40,827 | root | INFO | Starting up request id generator
# 2021-12-26 21:20:40,827 | root | INFO | Starting up app insight hooks
# 2021-12-26 21:20:40,827 | root | INFO | Invoking user's init function
# 2021-12-26 21:20:44,878 | root | INFO | Users's init has completed successfully
# 2021-12-26 21:20:44,891 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# 2021-12-26 21:20:44,891 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# Generating swagger file: /tmp/tmpoucryc48
# 2021-12-26 21:20:44,893 | root | INFO | Scoring timeout is found from os.environ: 60000 ms
# 2021-12-26 21:20:50,468 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:20:50 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:20:51,458 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:20:51 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:21:18,634 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:21:18 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:21:23,671 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:21:23 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:21:27,511 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:21:27 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:21:56,092 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:21:56 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:22:07,372 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:22:07 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
# 2021-12-26 21:22:31,017 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:22:31 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:22:32,828 | root | INFO | Validation Request Content-Type
# 2021-12-26 21:22:32,829 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-12-26 21:22:32,931 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:22:32 +0000] "POST /score?verbose=true HTTP/1.0" 200 24 "-" "Go-http-client/1.1"
# 2021-12-26 21:22:38,590 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:22:38 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:25:04,974 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:25:04 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:25:39,154 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:25:39 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:27:21,323 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:27:21 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:27:31,600 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:27:31 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:28:24,323 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:28:24 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
# 2021-12-26 21:37:44,345 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:37:44 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:37:56,024 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:37:56 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:39:48,095 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:39:48 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
# 2021-12-26 21:40:24,367 | root | INFO | 200
# 127.0.0.1 - - [26/Dec/2021:21:40:24 +0000] "GET /swagger.json HTTP/1.0" 200 3568 "-" "Go-http-client/1.1"
